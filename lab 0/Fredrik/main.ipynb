# %% [markdown]
# # Import modules

# %%
import torch
import torchvision
import torchvision.transforms as transforms
from torch import nn
from torch.utils.data import random_split, DataLoader, Subset
import torch.optim as optim
import matplotlib.pyplot as plt
import numpy as np
import os
from torch.utils.tensorboard import SummaryWriter
log_dir = "runs/CIFAR10"
os.makedirs(log_dir, exist_ok=True)
import datetime
import random

writer = SummaryWriter(log_dir)
print(f"TensorBoard logs will be saved to: {os.path.abspath(log_dir)}")

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

batch_size = 64
epochs = 50
patience = 5
import sys
# Out:
# TensorBoard logs will be saved to: /content/runs/CIFAR10
# Using device: cuda

# %% [markdown]
# # Task 1
# **Load dataset**

# %%
transform = transforms.Compose([
    transforms.Resize(224),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225]),
])

train_val_dataset = torchvision.datasets.CIFAR10(
    root='./data', train=True, download=True, transform=transform)
test_dataset = torchvision.datasets.CIFAR10(
    root='./data', train=False, download=True, transform=transform)

#ten_percent = int(0.1*len(train_val_dataset))
#indices = random.sample(range(len(train_val_dataset)), ten_percent)
#train_val_dataset = Subset(train_val_dataset, indices)

train_size = int(0.8* len(train_val_dataset))
val_size = len(train_val_dataset) - train_size
train_dataset, val_dataset = random_split(train_val_dataset, [train_size, val_size])

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=2)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=2)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=2)

print("Train samples:", len(train_dataset))
print("Validation samples:", len(val_dataset))
print("Test samples:", len(test_dataset))

examples = iter(train_loader)
images, labels = next(examples)
img_grid = torchvision.utils.make_grid(images[:16], nrow=4, normalize=True)
writer.add_image('CIFAR10_samples', img_grid)
writer.close()
# Out:
# 100%|██████████| 170M/170M [00:12<00:00, 13.2MB/s]
# Train samples: 40000
# Validation samples: 10000
# Test samples: 10000

# %% [markdown]
# **CNN**

# %%
class Net(nn.Module):
    def __init__(self, AF=nn.LeakyReLU(0.01)):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 6, 5)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.fc1 = nn.Linear(16 * 53 * 53, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)
        self.AF = AF

    def forward(self, x):
        x = self.pool(self.AF(self.conv1(x)))
        x = self.pool(self.AF(self.conv2(x)))
        x = x.view(-1, 16 * 53 * 53)
        x = self.AF(self.fc1(x))
        x = self.AF(self.fc2(x))
        x = self.fc3(x)
        return x

# %% [markdown]
# **Train Network**

# %%
def train_model(model, train_loader, val_loader, criterion, optimizer, device, model_name, epochs=10, patience=5):
    timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
    writer = SummaryWriter(f'runs/CIFAR10/{model_name}_{timestamp}')
    train_losses = []
    val_losses = []
    train_accuracies = []
    val_accuracies = []
    patience_counter = 0
    best_val_loss = float('inf')

    for epoch in range(epochs):
        running_train_loss = 0.0
        running_val_loss = 0.0
        correct_train = 0
        total_train = 0
        correct_val = 0
        total_val = 0

        model.train()
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_train_loss += loss.item()

            _, predicted = torch.max(outputs.data, 1)
            total_train += labels.size(0)
            correct_train += (predicted == labels).sum().item()

        avg_train_loss = running_train_loss / len(train_loader)
        train_accuracy = 100 * correct_train / total_train
        train_losses.append(avg_train_loss)
        train_accuracies.append(train_accuracy)

        model.eval()
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                running_val_loss += loss.item()

                _, predicted = torch.max(outputs.data, 1)
                total_val += labels.size(0)
                correct_val += (predicted == labels).sum().item()

        avg_val_loss = running_val_loss / len(val_loader)
        val_accuracy = 100 * correct_val / total_val
        val_losses.append(avg_val_loss)
        val_accuracies.append(val_accuracy)

        writer.add_scalars('Loss', {
            'train': avg_train_loss,
            'val': avg_val_loss
        }, epoch)

        writer.add_scalars('Accuracy', {
            'train': train_accuracy,
            'val': val_accuracy
        }, epoch)

        if avg_val_loss < best_val_loss:
            best_val_loss = avg_val_loss
            patience_counter = 0
            torch.save(model.state_dict(), model_name+'.pth')
        else:
            patience_counter += 1
            if patience_counter >= patience:
                print("Early stopping")
                break

        print(f"Epoch {epoch + 1}: Train Loss = {avg_train_loss:.4f}, Val Loss = {avg_val_loss:.4f}, Train Acc = {train_accuracy:.2f}%, Val Acc = {val_accuracy:.2f}%")

        if epoch % 5 == 0:
            for name, param in model.named_parameters():
                writer.add_histogram(name, param, epoch)

    model.load_state_dict(torch.load(model_name+'.pth'))
    writer.close()

    # Plot Training & Validation Loss
    plt.figure(figsize=(10, 4))
    plt.subplot(1, 2, 1)
    plt.plot(train_losses, label="Train Loss")
    plt.plot(val_losses, label="Validation Loss")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    plt.title("Loss Over Epochs")

    # Plot Training & Validation Accuracy
    plt.subplot(1, 2, 2)
    plt.plot(train_accuracies, label="Train Accuracy")
    plt.plot(val_accuracies, label="Validation Accuracy")
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy (%)")
    plt.legend()
    plt.title("Accuracy Over Epochs")
    plt.tight_layout()
    plt.show()

    return model, train_losses, val_losses, train_accuracies, val_accuracies

# %% [markdown]
# **Test Network**

# %%
def test_model(model, test_loader, criterion, device, model_name="model", tag_suffix=""):
    model.eval()
    total_loss = 0.0
    correct = 0
    total = 0

    timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
    writer = SummaryWriter(f'runs/CIFAR10/{model_name}_test_{timestamp}')

    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            total_loss += loss.item()

            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    avg_loss = total_loss / len(test_loader)
    accuracy = 100 * correct / total if total > 0 else 0

    print(f"Test Loss: {avg_loss:.4f}, Accuracy: {accuracy:.2f}%")

    # Log to TensorBoard
    writer.add_scalar(f'Test/Loss{tag_suffix}', avg_loss)
    writer.add_scalar(f'Test/Accuracy{tag_suffix}', accuracy)
    writer.close()

    return avg_loss, accuracy

# %% [markdown]
# **Train with LeakyReLU and SGD**

# %%
model_name_SGD = "model_SGD"
model_SGD = Net().to(device)
criterion_SGD = nn.CrossEntropyLoss()
optimizer_SGD = optim.SGD(model_SGD.parameters(), lr=0.0001)

model_SGD, train_losses_SGD, val_losses_SGD, train_accuracies_SGD, val_accuracies_SGD = train_model(model_SGD, train_loader, val_loader, criterion_SGD, optimizer_SGD,
                                                                                                    device, model_name_SGD, epochs, patience)
# Out:
# Epoch 1: Train Loss = 2.2998, Val Loss = 2.2952, Train Acc = 10.33%, Val Acc = 10.64%
# Epoch 2: Train Loss = 2.2896, Val Loss = 2.2849, Train Acc = 13.91%, Val Acc = 17.26%
# Epoch 3: Train Loss = 2.2783, Val Loss = 2.2717, Train Acc = 18.89%, Val Acc = 19.86%
# Epoch 4: Train Loss = 2.2629, Val Loss = 2.2535, Train Acc = 20.57%, Val Acc = 20.67%
# Epoch 5: Train Loss = 2.2419, Val Loss = 2.2295, Train Acc = 20.98%, Val Acc = 20.89%
# Epoch 6: Train Loss = 2.2157, Val Loss = 2.2013, Train Acc = 21.22%, Val Acc = 21.34%
# Epoch 7: Train Loss = 2.1875, Val Loss = 2.1735, Train Acc = 21.77%, Val Acc = 21.88%
# Epoch 8: Train Loss = 2.1605, Val Loss = 2.1477, Train Acc = 22.25%, Val Acc = 22.44%
# Epoch 9: Train Loss = 2.1352, Val Loss = 2.1242, Train Acc = 23.12%, Val Acc = 23.26%
# Epoch 10: Train Loss = 2.1110, Val Loss = 2.1013, Train Acc = 23.98%, Val Acc = 23.81%
# Epoch 11: Train Loss = 2.0873, Val Loss = 2.0789, Train Acc = 24.93%, Val Acc = 24.93%
# Epoch 12: Train Loss = 2.0644, Val Loss = 2.0583, Train Acc = 26.09%, Val Acc = 26.43%
# Epoch 13: Train Loss = 2.0428, Val Loss = 2.0383, Train Acc = 27.23%, Val Acc = 27.01%
# Epoch 14: Train Loss = 2.0226, Val Loss = 2.0201, Train Acc = 28.41%, Val Acc = 28.18%
# Epoch 15: Train Loss = 2.0039, Val Loss = 2.0033, Train Acc = 29.43%, Val Acc = 28.93%
# Epoch 16: Train Loss = 1.9867, Val Loss = 1.9879, Train Acc = 30.22%, Val Acc = 29.67%
# Epoch 17: Train Loss = 1.9706, Val Loss = 1.9733, Train Acc = 30.98%, Val Acc = 30.53%
# Epoch 18: Train Loss = 1.9556, Val Loss = 1.9600, Train Acc = 31.62%, Val Acc = 31.14%
# Epoch 19: Train Loss = 1.9411, Val Loss = 1.9466, Train Acc = 32.24%, Val Acc = 31.60%
# Epoch 20: Train Loss = 1.9274, Val Loss = 1.9340, Train Acc = 32.50%, Val Acc = 31.90%
# Epoch 21: Train Loss = 1.9138, Val Loss = 1.9222, Train Acc = 33.03%, Val Acc = 32.36%
# Epoch 22: Train Loss = 1.9009, Val Loss = 1.9105, Train Acc = 33.54%, Val Acc = 32.84%
# Epoch 23: Train Loss = 1.8882, Val Loss = 1.8995, Train Acc = 34.00%, Val Acc = 33.28%
# Epoch 24: Train Loss = 1.8758, Val Loss = 1.8877, Train Acc = 34.44%, Val Acc = 33.64%
# Epoch 25: Train Loss = 1.8635, Val Loss = 1.8766, Train Acc = 34.91%, Val Acc = 33.90%
# Epoch 26: Train Loss = 1.8511, Val Loss = 1.8670, Train Acc = 35.28%, Val Acc = 34.26%
# Epoch 27: Train Loss = 1.8390, Val Loss = 1.8551, Train Acc = 35.88%, Val Acc = 34.73%
# Epoch 28: Train Loss = 1.8267, Val Loss = 1.8432, Train Acc = 36.35%, Val Acc = 35.17%
# Epoch 29: Train Loss = 1.8142, Val Loss = 1.8324, Train Acc = 36.73%, Val Acc = 35.66%
# Epoch 30: Train Loss = 1.8016, Val Loss = 1.8207, Train Acc = 37.28%, Val Acc = 36.14%
# Epoch 31: Train Loss = 1.7884, Val Loss = 1.8104, Train Acc = 37.63%, Val Acc = 36.57%
# Epoch 32: Train Loss = 1.7751, Val Loss = 1.7964, Train Acc = 37.98%, Val Acc = 36.98%
# Epoch 33: Train Loss = 1.7609, Val Loss = 1.7840, Train Acc = 38.50%, Val Acc = 37.56%
# Epoch 34: Train Loss = 1.7470, Val Loss = 1.7728, Train Acc = 39.08%, Val Acc = 37.84%
# Epoch 35: Train Loss = 1.7329, Val Loss = 1.7591, Train Acc = 39.52%, Val Acc = 38.45%
# Epoch 36: Train Loss = 1.7189, Val Loss = 1.7506, Train Acc = 40.15%, Val Acc = 38.83%
# Epoch 37: Train Loss = 1.7061, Val Loss = 1.7382, Train Acc = 40.60%, Val Acc = 38.97%
# Epoch 38: Train Loss = 1.6937, Val Loss = 1.7275, Train Acc = 41.07%, Val Acc = 39.58%
# Epoch 39: Train Loss = 1.6820, Val Loss = 1.7177, Train Acc = 41.49%, Val Acc = 40.09%
# Epoch 40: Train Loss = 1.6710, Val Loss = 1.7096, Train Acc = 41.78%, Val Acc = 40.34%
# Epoch 41: Train Loss = 1.6607, Val Loss = 1.7020, Train Acc = 42.24%, Val Acc = 40.77%
# Epoch 42: Train Loss = 1.6512, Val Loss = 1.6988, Train Acc = 42.66%, Val Acc = 40.71%
# Epoch 43: Train Loss = 1.6422, Val Loss = 1.6892, Train Acc = 42.89%, Val Acc = 41.10%
# Epoch 44: Train Loss = 1.6331, Val Loss = 1.6832, Train Acc = 43.36%, Val Acc = 41.48%
# Epoch 45: Train Loss = 1.6254, Val Loss = 1.6767, Train Acc = 43.61%, Val Acc = 41.64%
# Epoch 46: Train Loss = 1.6172, Val Loss = 1.6722, Train Acc = 43.80%, Val Acc = 42.09%
# Epoch 47: Train Loss = 1.6095, Val Loss = 1.6687, Train Acc = 44.09%, Val Acc = 42.16%
# Epoch 48: Train Loss = 1.6020, Val Loss = 1.6643, Train Acc = 44.33%, Val Acc = 42.01%
# Epoch 49: Train Loss = 1.5947, Val Loss = 1.6583, Train Acc = 44.54%, Val Acc = 42.49%
# Epoch 50: Train Loss = 1.5875, Val Loss = 1.6529, Train Acc = 44.78%, Val Acc = 42.62%

# %% [markdown]
# **Test with LeakyReLU and SGD**

# %%
test_loss_SGD, test_accuracy_SGD = test_model(model_SGD, test_loader, criterion_SGD, device)
# Out:
# Test Loss: 1.6364, Accuracy: 42.86%

# %% [markdown]
# **Train with LeakyReLU and Adam**

# %%
model_name_Adam = "model_Adam"
model_Adam = Net().to(device)
criterion_Adam = nn.CrossEntropyLoss()
optimizer_Adam = optim.Adam(model_Adam.parameters(), lr=0.0001)

model_Adam, train_losses_Adam, val_losses_Adam, train_accuracies_Adam, val_accuracies_Adam = train_model(model_Adam, train_loader, val_loader, criterion_Adam, optimizer_Adam, device,
                                                                                                         model_name_Adam, epochs, patience)
# Out:
# Epoch 1: Train Loss = 1.6913, Val Loss = 1.5000, Train Acc = 40.07%, Val Acc = 46.79%
# Epoch 2: Train Loss = 1.3577, Val Loss = 1.3194, Train Acc = 52.02%, Val Acc = 52.96%
# Epoch 3: Train Loss = 1.2038, Val Loss = 1.2390, Train Acc = 57.33%, Val Acc = 56.45%
# Epoch 4: Train Loss = 1.0867, Val Loss = 1.2046, Train Acc = 62.00%, Val Acc = 57.69%
# Epoch 5: Train Loss = 0.9849, Val Loss = 1.2072, Train Acc = 65.33%, Val Acc = 57.72%
# Epoch 6: Train Loss = 0.8896, Val Loss = 1.1892, Train Acc = 69.27%, Val Acc = 59.15%
# Epoch 7: Train Loss = 0.7934, Val Loss = 1.2160, Train Acc = 72.64%, Val Acc = 58.82%
# Epoch 8: Train Loss = 0.6945, Val Loss = 1.2450, Train Acc = 76.17%, Val Acc = 59.22%
# Epoch 9: Train Loss = 0.5976, Val Loss = 1.2905, Train Acc = 79.84%, Val Acc = 59.20%
# Epoch 10: Train Loss = 0.5025, Val Loss = 1.3737, Train Acc = 83.35%, Val Acc = 59.02%
# Early stopping

# %% [markdown]
# **Test with LeakyReLU and Adam**

# %%
test_loss_Adamtanh, test_accuracy_Adamtanh = test_model(model_Adam, test_loader, criterion_Adam, device)
# Out:
# Test Loss: 1.1818, Accuracy: 59.13%

# %% [markdown]
# **Train with Tanh and Adam**

# %%
model_name_Adamtanh = "model_Adamtanh"
model_Adamtanh = Net(AF=nn.Tanh()).to(device)

criterion_Adamtanh = nn.CrossEntropyLoss()
optimizer_Adamtanh = optim.Adam(model_Adam.parameters(), lr=0.0001)

model_Adamtanh, train_losses_Adamtanh, val_losses_Adamtanh, train_accuracies_Adamtanh, val_accuracies_Adamtanh = train_model(model_Adamtanh, train_loader, val_loader, criterion_Adamtanh,
                                                                                                                             optimizer_Adamtanh, device, model_name_Adamtanh, epochs, patience)
# Out:
# Epoch 1: Train Loss = 2.3083, Val Loss = 2.3081, Train Acc = 9.30%, Val Acc = 9.30%
# Epoch 2: Train Loss = 2.3083, Val Loss = 2.3081, Train Acc = 9.30%, Val Acc = 9.30%
# Epoch 3: Train Loss = 2.3083, Val Loss = 2.3081, Train Acc = 9.30%, Val Acc = 9.30%
# Epoch 4: Train Loss = 2.3083, Val Loss = 2.3081, Train Acc = 9.30%, Val Acc = 9.30%
# Epoch 5: Train Loss = 2.3083, Val Loss = 2.3081, Train Acc = 9.30%, Val Acc = 9.30%
# Early stopping

# %% [markdown]
# **Test with Tanh and Adam**

# %%
test_loss_Adamtanh, test_accuracy_Adamtanh = test_model(model_Adamtanh, test_loader, criterion_Adamtanh, device)
# Out:
# Test Loss: 2.3078, Accuracy: 9.07%

# %% [markdown]
# # Task 2

# %% [markdown]
# **Fine Tuning**

# %%
model_AlexNetft = torch.hub.load('pytorch/vision:v0.10.0', 'alexnet', pretrained=False)
model_name_AlexNetft = "model_alexnetft"
num_ftrs = model_AlexNetft.classifier[6].in_features
model_AlexNetft.classifier[6] = nn.Linear(num_ftrs, 10)

model_AlexNetft.to(device)

criterion_AlexNetft = nn.CrossEntropyLoss()
optimizer_AlexNetft = optim.Adam(model_AlexNetft.parameters(), lr=0.0001)

model_AlexNetft, train_losses_AlexNetft, val_losses_AlexNetft, train_accuracies_AlexNetft, val_accuracies_AlexNetft = train_model(model_AlexNetft, train_loader, val_loader,
                                                                                                                                  criterion_AlexNetft, optimizer_AlexNetft, device,
                                                                                                                                  model_name_AlexNetft, epochs, patience)
test_loss_AlexNetft, test_accuracy_AlexNetft = test_model(model_AlexNetft, test_loader, criterion_AlexNetft, device)
# Out:
# Downloading: "https://github.com/pytorch/vision/zipball/v0.10.0" to /root/.cache/torch/hub/v0.10.0.zip
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# Epoch 1: Train Loss = 1.5682, Val Loss = 1.1805, Train Acc = 41.60%, Val Acc = 56.95%
# Epoch 2: Train Loss = 1.0867, Val Loss = 1.0099, Train Acc = 61.01%, Val Acc = 64.35%
# Epoch 3: Train Loss = 0.8504, Val Loss = 0.8792, Train Acc = 69.93%, Val Acc = 68.89%
# Epoch 4: Train Loss = 0.7027, Val Loss = 0.7132, Train Acc = 75.30%, Val Acc = 74.92%
# Epoch 5: Train Loss = 0.5944, Val Loss = 0.6510, Train Acc = 79.09%, Val Acc = 77.25%
# Epoch 6: Train Loss = 0.5032, Val Loss = 0.6181, Train Acc = 82.29%, Val Acc = 79.02%
# Epoch 7: Train Loss = 0.4258, Val Loss = 0.5875, Train Acc = 84.98%, Val Acc = 79.92%
# Epoch 8: Train Loss = 0.3588, Val Loss = 0.5949, Train Acc = 87.39%, Val Acc = 80.71%
# Epoch 9: Train Loss = 0.2968, Val Loss = 0.6170, Train Acc = 89.48%, Val Acc = 80.99%
# Epoch 10: Train Loss = 0.2482, Val Loss = 0.6400, Train Acc = 91.05%, Val Acc = 80.56%
# Epoch 11: Train Loss = 0.2063, Val Loss = 0.6075, Train Acc = 92.72%, Val Acc = 81.50%
# Early stopping
# Test Loss: 0.5935, Accuracy: 80.22%

# %% [markdown]
# **Feature Extraction**

# %%
model_AlexNetfe = torch.hub.load('pytorch/vision:v0.10.0', 'alexnet', pretrained=True)
model_name_AlexNetfe = "alexnetfe"

for param in model_AlexNetfe.features.parameters():
    param.requires_grad = False

num_ftrs = model_AlexNetfe.classifier[6].in_features
model_AlexNetfe.classifier[6] = nn.Linear(num_ftrs, 10)

model_AlexNetfe.to(device)

criterion_AlexNetfe = nn.CrossEntropyLoss()
optimizer_AlexNetfe = optim.Adam(filter(lambda p: p.requires_grad, model_AlexNetfe.parameters()), lr=0.0001)

model_AlexNetfe, train_losses_AlexNetfe, val_losses_AlexNetfe, train_accuracies_AlexNetfe, val_accuracies_AlexNetfe = train_model(model_AlexNetfe, train_loader, val_loader,
                                                                                                                                  criterion_AlexNetfe, optimizer_AlexNetfe, device,
                                                                                                                                  model_name_AlexNetfe, epochs, patience)
test_loss_AlexNetfe, test_accuracy_AlexNetfe = test_model(model_AlexNetfe, test_loader, criterion_AlexNetfe, device)
# Out:
# Using cache found in /root/.cache/torch/hub/pytorch_vision_v0.10.0
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/alexnet-owt-7be5be79.pth" to /root/.cache/torch/hub/checkpoints/alexnet-owt-7be5be79.pth
# 100%|██████████| 233M/233M [00:02<00:00, 102MB/s]
# Epoch 1: Train Loss = 0.6566, Val Loss = 0.4880, Train Acc = 76.89%, Val Acc = 82.91%
# Epoch 2: Train Loss = 0.4296, Val Loss = 0.4058, Train Acc = 84.88%, Val Acc = 85.72%
# Epoch 3: Train Loss = 0.3312, Val Loss = 0.4070, Train Acc = 88.25%, Val Acc = 86.12%
# Epoch 4: Train Loss = 0.2583, Val Loss = 0.3768, Train Acc = 90.81%, Val Acc = 87.34%
# Epoch 5: Train Loss = 0.2119, Val Loss = 0.3754, Train Acc = 92.41%, Val Acc = 87.51%
# Epoch 6: Train Loss = 0.1678, Val Loss = 0.4076, Train Acc = 94.04%, Val Acc = 86.91%
# Epoch 7: Train Loss = 0.1437, Val Loss = 0.3983, Train Acc = 94.81%, Val Acc = 87.43%
# Epoch 8: Train Loss = 0.1129, Val Loss = 0.4172, Train Acc = 95.94%, Val Acc = 87.39%
# Epoch 9: Train Loss = 0.0988, Val Loss = 0.4517, Train Acc = 96.55%, Val Acc = 87.01%
# Early stopping
# Test Loss: 0.3793, Accuracy: 87.14%

# %% [markdown]
# ## Explain (briefly!) what is the difference between the two runs and why there is a difference in performance

# %% [markdown]
# ## Transfer Learning from MNIST

# %% [markdown]
# **Load dataset**

# %%
transform = transforms.Compose([
    transforms.Pad(2),
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))
])

log_dir = "runs/MNIST"
os.makedirs(log_dir, exist_ok=True)

writer = SummaryWriter(log_dir)
print(f"TensorBoard logs will be saved to: {os.path.abspath(log_dir)}")

train_val_dataset = torchvision.datasets.MNIST(
    root='./data', train=True, download=True, transform=transform)
test_dataset = torchvision.datasets.MNIST(
    root='./data', train=False, download=True, transform=transform)

train_size = int(0.8* len(train_val_dataset))
val_size = len(train_val_dataset) - train_size
train_dataset, val_dataset = random_split(train_val_dataset, [train_size, val_size])

batch_size = 64
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=2)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=2)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=2)

print("Train samples:", len(train_dataset))
print("Validation samples:", len(val_dataset))
print("Test samples:", len(test_dataset))

examples = iter(train_loader)
images, labels = next(examples)
img_grid = torchvision.utils.make_grid(images[:16], nrow=4, normalize=True)
writer.add_image('MNIST_samples', img_grid)
writer.close()
# Out:
# TensorBoard logs will be saved to: /content/runs/MNIST
# 100%|██████████| 9.91M/9.91M [00:01<00:00, 5.09MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 133kB/s]
# 100%|██████████| 1.65M/1.65M [00:01<00:00, 1.26MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 8.31MB/s]
# Train samples: 48000
# Validation samples: 12000
# Test samples: 10000

# %% [markdown]
# **Initialize Model**

# %%
# LeNet-5
class LeNet5(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=6, kernel_size=5, stride=1)
        self.conv2 = nn.Conv2d(in_channels=6, out_channels=16, kernel_size=5, stride=1)
        self.conv3 = nn.Conv2d(in_channels=16, out_channels=120, kernel_size=5, stride=1)

        self.pool = nn.AvgPool2d(kernel_size=2, stride=2)

        self.tanh = nn.Tanh()

        self.fc1 = nn.Linear(in_features=120, out_features=84)
        self.fc2 = nn.Linear(in_features=84, out_features=10)

    def forward(self, x):
        x = self.pool(self.tanh(self.conv1(x)))
        x = self.pool(self.tanh(self.conv2(x)))
        x = self.tanh(self.conv3(x))

        x = x.view(x.size(0), -1)

        x = self.tanh(self.fc1(x))
        x = self.fc2(x)
        return x

# %% [markdown]
# **Train Model**

# %%
model_name_LeNet5 = "model_LeNet5"
model_LeNet5= LeNet5().to(device)
criterion_LeNet5 = nn.CrossEntropyLoss()
optimizer_LeNet5 = optim.Adam(model_LeNet5.parameters(), lr=0.0001)

model_LeNet5, train_losses_LeNet5, val_losses_LeNet5, train_accuracies_LeNet5, val_accuracies_LeNet5 = train_model(model_LeNet5, train_loader, val_loader, criterion_LeNet5,
                                                                                                                   optimizer_LeNet5, device, model_name_LeNet5, epochs, patience)
# Out:
# Epoch 1: Train Loss = 0.9074, Val Loss = 0.4036, Train Acc = 79.03%, Val Acc = 89.32%
# Epoch 2: Train Loss = 0.3297, Val Loss = 0.2705, Train Acc = 91.05%, Val Acc = 92.08%
# Epoch 3: Train Loss = 0.2402, Val Loss = 0.2055, Train Acc = 93.07%, Val Acc = 94.02%
# Epoch 4: Train Loss = 0.1857, Val Loss = 0.1614, Train Acc = 94.60%, Val Acc = 95.24%
# Epoch 5: Train Loss = 0.1472, Val Loss = 0.1308, Train Acc = 95.74%, Val Acc = 96.18%
# Epoch 6: Train Loss = 0.1206, Val Loss = 0.1103, Train Acc = 96.49%, Val Acc = 96.77%
# Epoch 7: Train Loss = 0.1016, Val Loss = 0.0961, Train Acc = 97.05%, Val Acc = 97.13%
# Epoch 8: Train Loss = 0.0878, Val Loss = 0.0856, Train Acc = 97.40%, Val Acc = 97.45%
# Epoch 9: Train Loss = 0.0772, Val Loss = 0.0776, Train Acc = 97.71%, Val Acc = 97.63%
# Epoch 10: Train Loss = 0.0686, Val Loss = 0.0723, Train Acc = 98.02%, Val Acc = 97.80%
# Epoch 11: Train Loss = 0.0617, Val Loss = 0.0680, Train Acc = 98.20%, Val Acc = 97.96%
# Epoch 12: Train Loss = 0.0564, Val Loss = 0.0646, Train Acc = 98.36%, Val Acc = 98.01%
# Epoch 13: Train Loss = 0.0515, Val Loss = 0.0604, Train Acc = 98.50%, Val Acc = 98.21%
# Epoch 14: Train Loss = 0.0474, Val Loss = 0.0580, Train Acc = 98.66%, Val Acc = 98.23%
# Epoch 15: Train Loss = 0.0439, Val Loss = 0.0538, Train Acc = 98.75%, Val Acc = 98.35%
# Epoch 16: Train Loss = 0.0407, Val Loss = 0.0528, Train Acc = 98.81%, Val Acc = 98.41%
# Epoch 17: Train Loss = 0.0380, Val Loss = 0.0513, Train Acc = 98.89%, Val Acc = 98.51%
# Epoch 18: Train Loss = 0.0357, Val Loss = 0.0484, Train Acc = 98.98%, Val Acc = 98.58%
# Epoch 19: Train Loss = 0.0334, Val Loss = 0.0485, Train Acc = 99.05%, Val Acc = 98.47%
# Epoch 20: Train Loss = 0.0311, Val Loss = 0.0481, Train Acc = 99.12%, Val Acc = 98.56%
# Epoch 21: Train Loss = 0.0294, Val Loss = 0.0461, Train Acc = 99.20%, Val Acc = 98.58%
# Epoch 22: Train Loss = 0.0276, Val Loss = 0.0446, Train Acc = 99.26%, Val Acc = 98.63%
# Epoch 23: Train Loss = 0.0260, Val Loss = 0.0457, Train Acc = 99.29%, Val Acc = 98.56%
# Epoch 24: Train Loss = 0.0246, Val Loss = 0.0444, Train Acc = 99.31%, Val Acc = 98.62%
# Epoch 25: Train Loss = 0.0233, Val Loss = 0.0430, Train Acc = 99.38%, Val Acc = 98.67%
# Epoch 26: Train Loss = 0.0216, Val Loss = 0.0481, Train Acc = 99.40%, Val Acc = 98.47%
# Epoch 27: Train Loss = 0.0207, Val Loss = 0.0413, Train Acc = 99.45%, Val Acc = 98.70%
# Epoch 28: Train Loss = 0.0193, Val Loss = 0.0422, Train Acc = 99.49%, Val Acc = 98.72%
# Epoch 29: Train Loss = 0.0184, Val Loss = 0.0410, Train Acc = 99.54%, Val Acc = 98.70%
# Epoch 30: Train Loss = 0.0173, Val Loss = 0.0419, Train Acc = 99.54%, Val Acc = 98.72%
# Epoch 31: Train Loss = 0.0164, Val Loss = 0.0449, Train Acc = 99.58%, Val Acc = 98.61%
# Epoch 32: Train Loss = 0.0155, Val Loss = 0.0423, Train Acc = 99.62%, Val Acc = 98.70%
# Epoch 33: Train Loss = 0.0146, Val Loss = 0.0408, Train Acc = 99.64%, Val Acc = 98.68%
# Epoch 34: Train Loss = 0.0138, Val Loss = 0.0404, Train Acc = 99.64%, Val Acc = 98.78%
# Epoch 35: Train Loss = 0.0129, Val Loss = 0.0401, Train Acc = 99.69%, Val Acc = 98.72%
# Epoch 36: Train Loss = 0.0121, Val Loss = 0.0401, Train Acc = 99.72%, Val Acc = 98.73%
# Epoch 37: Train Loss = 0.0117, Val Loss = 0.0433, Train Acc = 99.71%, Val Acc = 98.71%
# Epoch 38: Train Loss = 0.0107, Val Loss = 0.0396, Train Acc = 99.76%, Val Acc = 98.82%
# Epoch 39: Train Loss = 0.0102, Val Loss = 0.0395, Train Acc = 99.77%, Val Acc = 98.83%
# Epoch 40: Train Loss = 0.0097, Val Loss = 0.0408, Train Acc = 99.79%, Val Acc = 98.73%
# Epoch 41: Train Loss = 0.0091, Val Loss = 0.0413, Train Acc = 99.81%, Val Acc = 98.81%
# Epoch 42: Train Loss = 0.0085, Val Loss = 0.0385, Train Acc = 99.82%, Val Acc = 98.78%
# Epoch 43: Train Loss = 0.0081, Val Loss = 0.0412, Train Acc = 99.83%, Val Acc = 98.72%
# Epoch 44: Train Loss = 0.0075, Val Loss = 0.0408, Train Acc = 99.85%, Val Acc = 98.69%
# Epoch 45: Train Loss = 0.0069, Val Loss = 0.0448, Train Acc = 99.88%, Val Acc = 98.72%
# Epoch 46: Train Loss = 0.0066, Val Loss = 0.0404, Train Acc = 99.88%, Val Acc = 98.78%
# Early stopping

# %% [markdown]
# **Test Model**

# %%
test_loss_LeNet5, test_accuracy_LeNet5 = test_model(model_LeNet5, test_loader, criterion_LeNet5, device)
# Out:
# Test Loss: 0.0322, Accuracy: 98.92%

# %% [markdown]
# **Prepare SVHN dataset**

# %%
transform = transforms.Compose([
    transforms.Grayscale(num_output_channels=1),
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))
])

log_dir = "runs/SVHN"
os.makedirs(log_dir, exist_ok=True)

writer = SummaryWriter(log_dir)
print(f"TensorBoard logs will be saved to: {os.path.abspath(log_dir)}")

train_val_dataset = torchvision.datasets.SVHN(
    root='./data', split='train', download=True, transform=transform)
test_dataset = torchvision.datasets.SVHN(
    root='./data', split='test', download=True, transform=transform)

train_size = int(0.8* len(train_val_dataset))
val_size = len(train_val_dataset) - train_size
train_dataset, val_dataset = random_split(train_val_dataset, [train_size, val_size])

batch_size = 64
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=2)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=2)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=2)

print("Train samples:", len(train_dataset))
print("Validation samples:", len(val_dataset))
print("Test samples:", len(test_dataset))

examples = iter(train_loader)
images, labels = next(examples)
img_grid = torchvision.utils.make_grid(images[:16], nrow=4, normalize=True)
writer.add_image('MNIST_samples', img_grid)
writer.close()
# Out:
# TensorBoard logs will be saved to: /content/runs/SVHN
# Train samples: 58605
# Validation samples: 14652
# Test samples: 26032

# %% [markdown]
# **Train on SVHN using pretrained MNIST model. (Fine Tuning)**

# %%
model_name_SVHN = "model_SVHN"
model_SVHN = LeNet5().to(device)
model_SVHN.load_state_dict(torch.load(model_name_LeNet5 + '.pth'))
criterion_SVHN = nn.CrossEntropyLoss()
optimizer_SVHN = optim.Adam(model_SVHN.parameters(), lr=0.0001)

model_SVHN, train_losses_SVHN, val_losses_SVHN, train_accuracies_SVHN, val_accuracies_SVHN = train_model(
    model_SVHN, train_loader, val_loader, criterion_SVHN, optimizer_SVHN, device, model_name=model_name_SVHN)

test_loss_SVHN, test_accuracy_SVHN = test_model(
    model_SVHN, test_loader, criterion_SVHN, device, model_name=model_name_SVHN)
# Out:
# Epoch 1: Train Loss = 2.8690, Val Loss = 1.3429, Train Acc = 37.02%, Val Acc = 57.10%
# Epoch 2: Train Loss = 1.1144, Val Loss = 0.9541, Train Acc = 64.81%, Val Acc = 70.58%
# Epoch 3: Train Loss = 0.8715, Val Loss = 0.8120, Train Acc = 73.27%, Val Acc = 75.24%
# Epoch 4: Train Loss = 0.7600, Val Loss = 0.7348, Train Acc = 76.86%, Val Acc = 77.56%
# Epoch 5: Train Loss = 0.6931, Val Loss = 0.6898, Train Acc = 79.09%, Val Acc = 79.39%
# Epoch 6: Train Loss = 0.6471, Val Loss = 0.6459, Train Acc = 80.58%, Val Acc = 80.70%
# Epoch 7: Train Loss = 0.6110, Val Loss = 0.6103, Train Acc = 81.76%, Val Acc = 81.83%
# Epoch 8: Train Loss = 0.5823, Val Loss = 0.5880, Train Acc = 82.66%, Val Acc = 82.70%
# Epoch 9: Train Loss = 0.5587, Val Loss = 0.5726, Train Acc = 83.36%, Val Acc = 83.32%
# Epoch 10: Train Loss = 0.5381, Val Loss = 0.5485, Train Acc = 84.08%, Val Acc = 84.00%
# Test Loss: 0.6043, Accuracy: 82.33%

# %% [markdown]
# **Train on SVHN using pretrained MNIST model. (Feature extraction)**

# %%
model_SVHN_FE = LeNet5().to(device)
model_SVHN_FE.load_state_dict(torch.load(model_name_LeNet5 + '.pth'))


for param in model_SVHN_FE.conv1.parameters():
    param.requires_grad = False
for param in model_SVHN_FE.conv2.parameters():
    param.requires_grad = False
for param in model_SVHN_FE.conv3.parameters():
    param.requires_grad = False


criterion_SVHN_FE = nn.CrossEntropyLoss()
optimizer_SVHN_FE = optim.Adam(filter(lambda p: p.requires_grad, model_SVHN_FE.parameters()), lr=0.0001)

model_SVHN_FE, train_losses_SVHN_FE, val_losses_SVHN_FE, train_accuracies_SVHN_FE, val_accuracies_SVHN_FE = train_model(
    model_SVHN_FE, train_loader, val_loader, criterion_SVHN_FE, optimizer_SVHN_FE, device, model_name="model_SVHN_FE"
)

test_loss_SVHN_FE, test_accuracy_SVHN_FE = test_model(
    model_SVHN_FE, test_loader, criterion_SVHN_FE, device, model_name="model_SVHN_FE"
)
# Out:
# Epoch 1: Train Loss = 4.7764, Val Loss = 2.3271, Train Acc = 14.68%, Val Acc = 21.56%
# Epoch 2: Train Loss = 2.1954, Val Loss = 2.1335, Train Acc = 24.33%, Val Acc = 26.11%
# Epoch 3: Train Loss = 2.0652, Val Loss = 2.0235, Train Acc = 28.02%, Val Acc = 29.16%
# Epoch 4: Train Loss = 1.9591, Val Loss = 1.9195, Train Acc = 31.70%, Val Acc = 33.62%
# Epoch 5: Train Loss = 1.8592, Val Loss = 1.8220, Train Acc = 36.49%, Val Acc = 38.55%
# Epoch 6: Train Loss = 1.7620, Val Loss = 1.7289, Train Acc = 41.32%, Val Acc = 42.65%
# Epoch 7: Train Loss = 1.6734, Val Loss = 1.6465, Train Acc = 45.37%, Val Acc = 46.66%
# Epoch 8: Train Loss = 1.5926, Val Loss = 1.5701, Train Acc = 48.90%, Val Acc = 49.03%
# Epoch 9: Train Loss = 1.5249, Val Loss = 1.5102, Train Acc = 51.62%, Val Acc = 52.03%
# Epoch 10: Train Loss = 1.4707, Val Loss = 1.4642, Train Acc = 53.66%, Val Acc = 53.50%
# Test Loss: 1.4392, Accuracy: 55.16%

# %% [markdown]
# **Download Workspace**

# %%
# !zip -r /content/runs.zip /content/runs
from google.colab import files
files.download("/content/runs.zip")
files.download('model_SGD.pth')
files.download('model_Adam.pth')
files.download('model_Adamtanh.pth')
files.download('model_alexnetft.pth')
files.download('alexnetfe.pth')
files.download('model_LeNet5.pth')
files.download('model_SVHN.pth')
files.download('model_SVHN_FE.pth')
# Out:
#   adding: content/runs/ (stored 0%)
#   adding: content/runs/MNIST/ (stored 0%)
#   adding: content/runs/MNIST/events.out.tfevents.1743279753.62ace4296424.1247.32 (deflated 3%)
#   adding: content/runs/SVHN/ (stored 0%)
#   adding: content/runs/SVHN/events.out.tfevents.1743280695.62ace4296424.1247.45 (deflated 1%)
#   adding: content/runs/SVHN/events.out.tfevents.1743280444.62ace4296424.1247.43 (deflated 1%)
#   adding: content/runs/SVHN/events.out.tfevents.1743280437.62ace4296424.1247.42 (deflated 0%)
#   adding: content/runs/SVHN/events.out.tfevents.1743280189.62ace4296424.1247.40 (deflated 0%)
#   adding: content/runs/SVHN/events.out.tfevents.1743280138.62ace4296424.1247.39 (deflated 9%)
#   adding: content/runs/CIFAR10/ (stored 0%)
#   adding: content/runs/CIFAR10/model_test_20250329_202857/ (stored 0%)
#   adding: content/runs/CIFAR10/model_test_20250329_202857/events.out.tfevents.1743280137.62ace4296424.1247.38 (deflated 15%)
#   adding: content/runs/CIFAR10/model_test_20250329_195021/ (stored 0%)
#   adding: content/runs/CIFAR10/model_test_20250329_195021/events.out.tfevents.1743277821.62ace4296424.1247.6 (deflated 14%)
#   adding: content/runs/CIFAR10/model_test_20250329_201446/ (stored 0%)
#   adding: content/runs/CIFAR10/model_test_20250329_201446/events.out.tfevents.1743279286.62ace4296424.1247.25 (deflated 14%)
#   adding: content/runs/CIFAR10/model_SVHN_20250329_203409/ (stored 0%)
#   adding: content/runs/CIFAR10/model_SVHN_20250329_203409/events.out.tfevents.1743280449.62ace4296424.1247.44 (deflated 9%)
#   adding: content/runs/CIFAR10/model_Adamtanh_20250329_200109/ (stored 0%)
#   adding: content/runs/CIFAR10/model_Adamtanh_20250329_200109/Accuracy_val/ (stored 0%)
#   adding: content/runs/CIFAR10/model_Adamtanh_20250329_200109/Accuracy_val/events.out.tfevents.1743278513.62ace4296424.1247.18 (deflated 44%)
#   adding: content/runs/CIFAR10/model_Adamtanh_20250329_200109/Loss_train/ (stored 0%)
#   adding: content/runs/CIFAR10/model_Adamtanh_20250329_200109/Loss_train/events.out.tfevents.1743278513.62ace4296424.1247.15 (deflated 42%)
#   adding: content/runs/CIFAR10/model_Adamtanh_20250329_200109/events.out.tfevents.1743278469.62ace4296424.1247.14 (deflated 93%)
#   adding: content/runs/CIFAR10/model_Adamtanh_20250329_200109/Accuracy_train/ (stored 0%)
#   adding: content/runs/CIFAR10/model_Adamtanh_20250329_200109/Accuracy_train/events.out.tfevents.1743278513.62ace4296424.1247.17 (deflated 44%)
#   adding: content/runs/CIFAR10/model_Adamtanh_20250329_200109/Loss_val/ (stored 0%)
#   adding: content/runs/CIFAR10/model_Adamtanh_20250329_200109/Loss_val/events.out.tfevents.1743278513.62ace4296424.1247.16 (deflated 41%)
#   adding: content/runs/CIFAR10/events.out.tfevents.1743275555.62ace4296424.1247.0 (deflated 0%)
#   adding: content/runs/CIFAR10/model_test_20250329_200535/ (stored 0%)
#   adding: content/runs/CIFAR10/model_test_20250329_200535/events.out.tfevents.1743278735.62ace4296424.1247.19 (deflated 14%)
#   adding: content/runs/CIFAR10/model_alexnetft_20250329_200548/ (stored 0%)
#   adding: content/runs/CIFAR10/model_alexnetft_20250329_200548/Accuracy_val/ (stored 0%)
#   adding: content/runs/CIFAR10/model_alexnetft_20250329_200548/Accuracy_val/events.out.tfevents.1743278793.62ace4296424.1247.24 (deflated 47%)
#   adding: content/runs/CIFAR10/model_alexnetft_20250329_200548/Loss_train/ (stored 0%)
#   adding: content/runs/CIFAR10/model_alexnetft_20250329_200548/Loss_train/events.out.tfevents.1743278793.62ace4296424.1247.21 (deflated 43%)
#   adding: content/runs/CIFAR10/model_alexnetft_20250329_200548/Accuracy_train/ (stored 0%)
#   adding: content/runs/CIFAR10/model_alexnetft_20250329_200548/Accuracy_train/events.out.tfevents.1743278793.62ace4296424.1247.23 (deflated 47%)
#   adding: content/runs/CIFAR10/model_alexnetft_20250329_200548/Loss_val/ (stored 0%)
#   adding: content/runs/CIFAR10/model_alexnetft_20250329_200548/Loss_val/events.out.tfevents.1743278793.62ace4296424.1247.22 (deflated 43%)
#   adding: content/runs/CIFAR10/model_alexnetft_20250329_200548/events.out.tfevents.1743278748.62ace4296424.1247.20 (deflated 93%)
#   adding: content/runs/CIFAR10/model_SVHN_20250329_203822/ (stored 0%)
#   adding: content/runs/CIFAR10/model_SVHN_20250329_203822/events.out.tfevents.1743280702.62ace4296424.1247.46 (deflated 95%)
#   adding: content/runs/CIFAR10/model_SVHN_20250329_203822/Accuracy_val/ (stored 0%)
#   adding: content/runs/CIFAR10/model_SVHN_20250329_203822/Accuracy_val/events.out.tfevents.1743280712.62ace4296424.1247.50 (deflated 45%)
#   adding: content/runs/CIFAR10/model_SVHN_20250329_203822/Loss_train/ (stored 0%)
#   adding: content/runs/CIFAR10/model_SVHN_20250329_203822/Loss_train/events.out.tfevents.1743280712.62ace4296424.1247.47 (deflated 41%)
#   adding: content/runs/CIFAR10/model_SVHN_20250329_203822/Accuracy_train/ (stored 0%)
#   adding: content/runs/CIFAR10/model_SVHN_20250329_203822/Accuracy_train/events.out.tfevents.1743280712.62ace4296424.1247.49 (deflated 45%)
#   adding: content/runs/CIFAR10/model_SVHN_20250329_203822/Loss_val/ (stored 0%)
#   adding: content/runs/CIFAR10/model_SVHN_20250329_203822/Loss_val/events.out.tfevents.1743280712.62ace4296424.1247.48 (deflated 41%)
#   adding: content/runs/CIFAR10/model_SVHN_FE_20250329_204015/ (stored 0%)
#   adding: content/runs/CIFAR10/model_SVHN_FE_20250329_204015/events.out.tfevents.1743280815.62ace4296424.1247.52 (deflated 95%)
#   adding: content/runs/CIFAR10/model_SVHN_FE_20250329_204015/Accuracy_val/ (stored 0%)
#   adding: content/runs/CIFAR10/model_SVHN_FE_20250329_204015/Accuracy_val/events.out.tfevents.1743280824.62ace4296424.1247.56 (deflated 45%)
#   adding: content/runs/CIFAR10/model_SVHN_FE_20250329_204015/Loss_train/ (stored 0%)
#   adding: content/runs/CIFAR10/model_SVHN_FE_20250329_204015/Loss_train/events.out.tfevents.1743280824.62ace4296424.1247.53 (deflated 41%)
#   adding: content/runs/CIFAR10/model_SVHN_FE_20250329_204015/Accuracy_train/ (stored 0%)
#   adding: content/runs/CIFAR10/model_SVHN_FE_20250329_204015/Accuracy_train/events.out.tfevents.1743280824.62ace4296424.1247.55 (deflated 45%)
#   adding: content/runs/CIFAR10/model_SVHN_FE_20250329_204015/Loss_val/ (stored 0%)
#   adding: content/runs/CIFAR10/model_SVHN_FE_20250329_204015/Loss_val/events.out.tfevents.1743280824.62ace4296424.1247.54 (deflated 41%)
#   adding: content/runs/CIFAR10/alexnetfe_20250329_201458/ (stored 0%)
#   adding: content/runs/CIFAR10/alexnetfe_20250329_201458/events.out.tfevents.1743279298.62ace4296424.1247.26 (deflated 92%)
#   adding: content/runs/CIFAR10/alexnetfe_20250329_201458/Accuracy_val/ (stored 0%)
#   adding: content/runs/CIFAR10/alexnetfe_20250329_201458/Accuracy_val/events.out.tfevents.1743279342.62ace4296424.1247.30 (deflated 45%)
#   adding: content/runs/CIFAR10/alexnetfe_20250329_201458/Loss_train/ (stored 0%)
#   adding: content/runs/CIFAR10/alexnetfe_20250329_201458/Loss_train/events.out.tfevents.1743279342.62ace4296424.1247.27 (deflated 42%)
#   adding: content/runs/CIFAR10/alexnetfe_20250329_201458/Accuracy_train/ (stored 0%)
#   adding: content/runs/CIFAR10/alexnetfe_20250329_201458/Accuracy_train/events.out.tfevents.1743279342.62ace4296424.1247.29 (deflated 45%)
#   adding: content/runs/CIFAR10/alexnetfe_20250329_201458/Loss_val/ (stored 0%)
#   adding: content/runs/CIFAR10/alexnetfe_20250329_201458/Loss_val/events.out.tfevents.1743279342.62ace4296424.1247.28 (deflated 41%)
#   adding: content/runs/CIFAR10/model_SVHN_FE_test_20250329_204156/ (stored 0%)
#   adding: content/runs/CIFAR10/model_SVHN_FE_test_20250329_204156/events.out.tfevents.1743280916.62ace4296424.1247.57 (deflated 14%)
#   adding: content/runs/CIFAR10/model_Adam_20250329_195030/ (stored 0%)
#   adding: content/runs/CIFAR10/model_Adam_20250329_195030/Accuracy_val/ (stored 0%)
#   adding: content/runs/CIFAR10/model_Adam_20250329_195030/Accuracy_val/events.out.tfevents.1743277874.62ace4296424.1247.11 (deflated 47%)
#   adding: content/runs/CIFAR10/model_Adam_20250329_195030/Loss_train/ (stored 0%)
#   adding: content/runs/CIFAR10/model_Adam_20250329_195030/Loss_train/events.out.tfevents.1743277874.62ace4296424.1247.8 (deflated 42%)
#   adding: content/runs/CIFAR10/model_Adam_20250329_195030/Accuracy_train/ (stored 0%)
#   adding: content/runs/CIFAR10/model_Adam_20250329_195030/Accuracy_train/events.out.tfevents.1743277874.62ace4296424.1247.10 (deflated 45%)
#   adding: content/runs/CIFAR10/model_Adam_20250329_195030/Loss_val/ (stored 0%)
#   adding: content/runs/CIFAR10/model_Adam_20250329_195030/Loss_val/events.out.tfevents.1743277874.62ace4296424.1247.9 (deflated 42%)
#   adding: content/runs/CIFAR10/model_Adam_20250329_195030/events.out.tfevents.1743277830.62ace4296424.1247.7 (deflated 94%)
#   adding: content/runs/CIFAR10/model_SGD_20250329_191304/ (stored 0%)
#   adding: content/runs/CIFAR10/model_SGD_20250329_191304/Accuracy_val/ (stored 0%)
#   adding: content/runs/CIFAR10/model_SGD_20250329_191304/Accuracy_val/events.out.tfevents.1743275629.62ace4296424.1247.5 (deflated 58%)
#   adding: content/runs/CIFAR10/model_SGD_20250329_191304/Loss_train/ (stored 0%)
#   adding: content/runs/CIFAR10/model_SGD_20250329_191304/Loss_train/events.out.tfevents.1743275629.62ace4296424.1247.2 (deflated 53%)
#   adding: content/runs/CIFAR10/model_SGD_20250329_191304/Accuracy_train/ (stored 0%)
#   adding: content/runs/CIFAR10/model_SGD_20250329_191304/Accuracy_train/events.out.tfevents.1743275629.62ace4296424.1247.4 (deflated 58%)
#   adding: content/runs/CIFAR10/model_SGD_20250329_191304/Loss_val/ (stored 0%)
#   adding: content/runs/CIFAR10/model_SGD_20250329_191304/Loss_val/events.out.tfevents.1743275629.62ace4296424.1247.3 (deflated 53%)
#   adding: content/runs/CIFAR10/model_SGD_20250329_191304/events.out.tfevents.1743275584.62ace4296424.1247.1 (deflated 96%)
#   adding: content/runs/CIFAR10/model_SVHN_test_20250329_204004/ (stored 0%)
#   adding: content/runs/CIFAR10/model_SVHN_test_20250329_204004/events.out.tfevents.1743280804.62ace4296424.1247.51 (deflated 15%)
#   adding: content/runs/CIFAR10/model_LeNet5_20250329_202245/ (stored 0%)
#   adding: content/runs/CIFAR10/model_LeNet5_20250329_202245/Accuracy_val/ (stored 0%)
#   adding: content/runs/CIFAR10/model_LeNet5_20250329_202245/Accuracy_val/events.out.tfevents.1743279773.62ace4296424.1247.37 (deflated 59%)
#   adding: content/runs/CIFAR10/model_LeNet5_20250329_202245/Loss_train/ (stored 0%)
#   adding: content/runs/CIFAR10/model_LeNet5_20250329_202245/Loss_train/events.out.tfevents.1743279773.62ace4296424.1247.34 (deflated 53%)
#   adding: content/runs/CIFAR10/model_LeNet5_20250329_202245/Accuracy_train/ (stored 0%)
#   adding: content/runs/CIFAR10/model_LeNet5_20250329_202245/Accuracy_train/events.out.tfevents.1743279773.62ace4296424.1247.36 (deflated 58%)
#   adding: content/runs/CIFAR10/model_LeNet5_20250329_202245/events.out.tfevents.1743279765.62ace4296424.1247.33 (deflated 97%)
#   adding: content/runs/CIFAR10/model_LeNet5_20250329_202245/Loss_val/ (stored 0%)
#   adding: content/runs/CIFAR10/model_LeNet5_20250329_202245/Loss_val/events.out.tfevents.1743279773.62ace4296424.1247.35 (deflated 53%)
#   adding: content/runs/CIFAR10/model_test_20250329_195840/ (stored 0%)
#   adding: content/runs/CIFAR10/model_test_20250329_195840/events.out.tfevents.1743278320.62ace4296424.1247.12 (deflated 15%)
#   adding: content/runs/CIFAR10/model_test_20250329_202224/ (stored 0%)
#   adding: content/runs/CIFAR10/model_test_20250329_202224/events.out.tfevents.1743279744.62ace4296424.1247.31 (deflated 14%)
#   adding: content/runs/CIFAR10/model_Adamtanh_20250329_195849/ (stored 0%)
#   adding: content/runs/CIFAR10/model_Adamtanh_20250329_195849/events.out.tfevents.1743278329.62ace4296424.1247.13 (deflated 9%)
#   adding: content/runs/CIFAR10/model_SVHN_20250329_203219/ (stored 0%)
#   adding: content/runs/CIFAR10/model_SVHN_20250329_203219/events.out.tfevents.1743280339.62ace4296424.1247.41 (deflated 9%)
